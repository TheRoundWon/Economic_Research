# %% [markdown]
# # Nobebook for Stock Information
#
# Description:
# Notebook shows how to build your own Stock Database

# %%
# Importing your Library

## Standard Libraries
import pandas as pd
import numpy as np
import requests
import os
from IPython import display
import json
import enum
import sys
from datetime import datetime, timedelta

## Learning Libraries and External Libraries
from sqlalchemy import create_engine, Table, Column, ForeignKey, Integer, String, DateTime, Boolean, ARRAY, DATE, FLOAT, Enum, TIME, BigInteger
from sqlalchemy import select, insert, within_group, exists
from sqlalchemy.orm import declarative_base, relationship, Session
import mysql.connector as mysql
import sqlalchemy

## Datasource Modules
from fredapi import Fred
import wbgapi as wb


## Custom Modules
from MasterEconomist import *

# %% [markdown]
# # Initiation the OBJECT and CONNECTION

# %%
fred = Fred(api_key=os.environ['FRED_KEY'])
engine = create_engine(f"mysql+mysqlconnector://{os.environ['USER']}:\
    {os.environ['PASSWORD']}@{os.environ['PI']}/{os.environ['MAIN_DB']}" )
url = "https://www.alphavantage.co/query"

# %% [markdown]
# # Map the ORMs for the relevant Financial information for target stocks

# %%
Base = declarative_base()

class Stock_Mapper(Base):
    __tablename__ = "stock_symbol_mapping"
    symbol = Column(String(35), primary_key=True)
    company_name = Column(String(100))
    region = Column(String(30))
    currency = Column(String(3))
    asset_type = Column(String(25))
    marketOpen = Column(TIME)
    marketClose = Column(TIME)
    timezone = Column(String(10))

class ReportingTypes(enum.Enum):
    quarterlyReport = 1
    annualReport = 2

class Denominations(enum.Enum):
    k = 1
    m = 2
    b = 3


class Income_Statement(Base):
    __tablename__ = "income_statements"
    id = Column(Integer, primary_key=True)
    symbol = Column(String(35), ForeignKey('stock_symbol_mapping.symbol'))
    reporting_type = Column(Enum(ReportingTypes))
    reporting_denominations = Column(Enum(Denominations))
    fiscalDateEnding = Column(DATE) 
    reportedCurrency = Column(String(3))
    grossProfit = Column(FLOAT) 
    totalRevenue = Column(FLOAT)
    costOfRevenue = Column(FLOAT)
    costofGoodsAndServicesSold = Column(FLOAT)
    operatingIncome = Column(FLOAT) 
    sellingGeneralAndAdministrative = Column(FLOAT)
    researchAndDevelopment = Column(FLOAT)
    operatingExpenses = Column(FLOAT)
    investmentIncomeNet = Column(FLOAT)
    netInterestIncome = Column(FLOAT)
    interestIncome = Column(FLOAT)
    interestExpense = Column(FLOAT)
    nonInterestIncome = Column(FLOAT)
    otherNonOperatingIncome = Column(FLOAT)
    depreciation = Column(FLOAT)
    depreciationAndAmortization = Column(FLOAT)
    incomeBeforeTax = Column(FLOAT)
    incomeTaxExpense = Column(FLOAT)
    interestAndDebtExpense = Column(FLOAT)
    netIncomeFromContinuingOperations = Column(FLOAT)
    comprehensiveIncomeNetOfTax = Column(FLOAT)
    ebit = Column(FLOAT)
    ebitda = Column(FLOAT)
    netIncome = Column(FLOAT)

class Balance_Sheet(Base):
    __tablename__ = "balance_sheet"
    id = Column(Integer, primary_key=True)
    symbol = Column(String(35), ForeignKey('stock_symbol_mapping.symbol'))
    reporting_type = Column(Enum(ReportingTypes))
    reporting_denominations = Column(Enum(Denominations))
    fiscalDateEnding = Column(DATE)
    totalAssets = Column(FLOAT) 
    totalCurrentAssets =  Column(FLOAT)
    cashAndCashEquivalentsAtCarryingValue = Column(FLOAT)
    cashAndShortTermInvestments = Column(FLOAT)
    inventory = Column(FLOAT)
    currentNetReceivables = Column(FLOAT) 
    totalNonCurrentAssets = Column(FLOAT)
    propertyPlantEquipment = Column(FLOAT) 
    accumulatedDepreciationAmortizationPPE = Column(FLOAT) 
    intangibleAssets = Column(FLOAT) 
    intangibleAssetsExcludingGoodwill = Column(FLOAT) 
    goodwill = Column(FLOAT) 
    investments = Column(FLOAT) 
    longTermInvestments = Column(FLOAT) 
    shortTermInvestments = Column(FLOAT) 
    otherCurrentAssets = Column(FLOAT)
    otherNonCurrrentAssets = Column(FLOAT) 
    totalLiabilities = Column(FLOAT) 
    totalCurrentLiabilities = Column(FLOAT) 
    currentAccountsPayable = Column(FLOAT) 
    deferredRevenue = Column(FLOAT) 
    currentDebt = Column(FLOAT) 
    shortTermDebt = Column(FLOAT) 
    totalNonCurrentLiabilities = Column(FLOAT) 
    capitalLeaseObligations = Column(FLOAT) 
    longTermDebt = Column(FLOAT) 
    currentLongTermDebt = Column(FLOAT) 
    longTermDebtNoncurrent = Column(FLOAT) 
    shortLongTermDebtTotal = Column(FLOAT) 
    otherCurrentLiabilities = Column(FLOAT) 
    otherNonCurrentLiabilities = Column(FLOAT) 
    totalShareholderEquity = Column(FLOAT) 
    treasuryStock = Column(FLOAT) 
    retainedEarnings = Column(FLOAT) 
    commonStock = Column(FLOAT) 
    commonStockSharesOutstanding = Column(FLOAT) 

class CashFlow(Base):
    __tablename__ = "cashflow"
    id = Column(Integer, primary_key=True)
    symbol = Column(String(35), ForeignKey('stock_symbol_mapping.symbol'))
    reporting_type = Column(Enum(ReportingTypes))
    reporting_denominations = Column(Enum(Denominations))
    fiscalDateEnding = Column(DATE)
    operatingCashflow = Column(FLOAT) 
    paymentsForOperatingActivities = Column(FLOAT) 
    proceedsFromOperatingActivities = Column(FLOAT) 
    changeInOperatingLiabilities = Column(FLOAT) 
    changeInOperatingAssets = Column(FLOAT) 
    depreciationDepletionAndAmortization = Column(FLOAT) 
    capitalExpenditures = Column(FLOAT) 
    changeInReceivables = Column(FLOAT) 
    changeInInventory = Column(FLOAT) 
    profitLoss = Column(FLOAT) 
    cashflowFromInvestment = Column(FLOAT) 
    cashflowFromFinancing = Column(FLOAT) 
    proceedsFromRepaymentsOfShortTermDebt = Column(FLOAT) 
    paymentsForRepurchaseOfCommonStock = Column(FLOAT) 
    paymentsForRepurchaseOfEquity = Column(FLOAT) 
    paymentsForRepurchaseOfPreferredStock = Column(FLOAT) 
    dividendPayout = Column(FLOAT) 
    dividendPayoutCommonStock = Column(FLOAT) 
    dividendPayoutPreferredStock = Column(FLOAT) 
    proceedsFromIssuanceOfCommonStock = Column(FLOAT) 
    proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet = Column(FLOAT) 
    proceedsFromIssuanceOfPreferredStock = Column(FLOAT) 
    proceedsFromRepurchaseOfEquity = Column(FLOAT) 
    proceedsFromSaleOfTreasuryStock = Column(FLOAT) 
    changeInCashAndCashEquivalents = Column(FLOAT) 
    changeInExchangeRate = Column(FLOAT) 
    netIncome = Column(FLOAT) 


class Stock_Meta(Base):
    __tablename__ = "stock_meta"
    symbol = Column(String(35), primary_key=True)
    assetSubType = Column(String(50))
    companyFullName = Column(String(255))
    cik = Column(Integer)
    exchange = Column(String(30))
    currency = Column(String(3))
    country = Column(String(3))
    sector = Column(String(50))
    industry = Column(String(150))
    address = Column(String(150))
    fiscalYearEnd = Column(String(30))

class Earnings(Base):
    __tablename__ = "earnings"
    id = Column(Integer, primary_key=True)
    symbol = Column(String(35), ForeignKey('stock_symbol_mapping.symbol'))
    reporting_type = Column(Enum(ReportingTypes))
    reporting_denominations = Column(Enum(Denominations))
    fiscalDateEnding = Column(DATE)
    reportedDate = Column(FLOAT)
    reportedEPS = Column(FLOAT)
    estimatedEPS = Column(FLOAT) 
    annualEPS = Column(FLOAT)
    surprise = Column(FLOAT)
    surprisePercentage = Column(FLOAT)

# %%
denom_mapper = {'b': 1_000_000_000, 'm': 1_000_000, 'k': 1_000}

# %%
output2['quarterlyEarnings']
# Out:
# [{'fiscalDateEnding': '2022-03-31',
#   'reportedDate': '2022-04-14',
#   'reportedEPS': 'None',
#   'estimatedEPS': '1.57',
#   'surprise': 'None',
#   'surprisePercentage': 'None'},
#  {'fiscalDateEnding': '2021-12-31',
#   'reportedDate': '2022-01-14',
#   'reportedEPS': '1.46',
#   'estimatedEPS': '1.38',
#   'surprise': '0.08',
#   'surprisePercentage': '5.7971'},
#  {'fiscalDateEnding': '2021-09-30',
#   'reportedDate': '2021-10-14',
#   'reportedEPS': '2.15',
#   'estimatedEPS': '1.7852',
#   'surprise': '0.3648',
#   'surprisePercentage': '20.4347'},
#  {'fiscalDateEnding': '2021-06-30',
#   'reportedDate': '2021-07-14',
#   'reportedEPS': '2.84',
#   'estimatedEPS': '1.8908',
#   'surprise': '0.9492',
#   'surprisePercentage': '50.201'},
#  {'fiscalDateEnding': '2021-03-31',
#   'reportedDate': '2021-04-15',
#   'reportedEPS': '3.62',
#   'estimatedEPS': '2.5309',
#   'surprise': '1.0891',
#   'surprisePercentage': '43.0321'},
#  {'fiscalDateEnding': '2020-12-31',
#   'reportedDate': '2021-01-15',
#   'reportedEPS': '2.07',
#   'estimatedEPS': '1.3098',
#   'surprise': '0.7602',
#   'surprisePercentage': '58.0394'},
#  {'fiscalDateEnding': '2020-09-30',
#   'reportedDate': '2020-10-13',
#   'reportedEPS': '1.4',
#   'estimatedEPS': '0.8729',
#   'surprise': '0.5271',
#   'surprisePercentage': '60.3849'},
#  {'fiscalDateEnding': '2020-06-30',
#   'reportedDate': '2020-07-14',
#   'reportedEPS': '0.51',
#   'estimatedEPS': '0.3226',
#   'surprise': '0.1874',
#   'surprisePercentage': '58.0905'},
#  {'fiscalDateEnding': '2020-03-31',
#   'reportedDate': '2020-04-15',
#   'reportedEPS': '1.06',
#   'estimatedEPS': '1.5698',
#   'surprise': '-0.5098',
#   'surprisePercentage': '-32.4755'},
#  {'fiscalDateEnding': '2019-12-31',
#   'reportedDate': '2020-01-14',
#   'reportedEPS': '1.9',
#   'estimatedEPS': '1.7969',
#   'surprise': '0.1031',
#   'surprisePercentage': '5.7377'},
#  {'fiscalDateEnding': '2019-09-30',
#   'reportedDate': '2019-10-15',
#   'reportedEPS': '1.97',
#   'estimatedEPS': '1.9502',
#   'surprise': '0.0198',
#   'surprisePercentage': '1.0153'},
#  {'fiscalDateEnding': '2019-06-30',
#   'reportedDate': '2019-07-15',
#   'reportedEPS': '1.83',
#   'estimatedEPS': '1.8059',
#   'surprise': '0.0241',
#   'surprisePercentage': '1.3345'},
#  {'fiscalDateEnding': '2019-03-31',
#   'reportedDate': '2019-04-15',
#   'reportedEPS': '1.87',
#   'estimatedEPS': '1.7941',
#   'surprise': '0.0759',
#   'surprisePercentage': '4.2305'},
#  {'fiscalDateEnding': '2018-12-31',
#   'reportedDate': '2019-01-14',
#   'reportedEPS': '1.61',
#   'estimatedEPS': '1.5464',
#   'surprise': '0.0636',
#   'surprisePercentage': '4.1128'},
#  {'fiscalDateEnding': '2018-09-30',
#   'reportedDate': '2018-10-12',
#   'reportedEPS': '1.73',
#   'estimatedEPS': '1.6601',
#   'surprise': '0.0699',
#   'surprisePercentage': '4.2106'},
#  {'fiscalDateEnding': '2018-06-30',
#   'reportedDate': '2018-07-13',
#   'reportedEPS': '1.63',
#   'estimatedEPS': '1.5552',
#   'surprise': '0.0748',
#   'surprisePercentage': '4.8097'},
#  {'fiscalDateEnding': '2018-03-31',
#   'reportedDate': '2018-04-13',
#   'reportedEPS': '1.68',
#   'estimatedEPS': '1.6029',
#   'surprise': '0.0771',
#   'surprisePercentage': '4.81'},
#  {'fiscalDateEnding': '2017-12-31',
#   'reportedDate': '2018-01-16',
#   'reportedEPS': '1.2',
#   'estimatedEPS': '1.1908',
#   'surprise': '0.0092',
#   'surprisePercentage': '0.7726'},
#  {'fiscalDateEnding': '2017-09-30',
#   'reportedDate': '2017-10-12',
#   'reportedEPS': '1.29',
#   'estimatedEPS': '1.2993',
#   'surprise': '-0.0093',
#   'surprisePercentage': '-0.7158'},
#  {'fiscalDateEnding': '2017-06-30',
#   'reportedDate': '2017-07-14',
#   'reportedEPS': '1.28',
#   'estimatedEPS': '1.2082',
#   'surprise': '0.0718',
#   'surprisePercentage': '5.9427'},
#  {'fiscalDateEnding': '2017-03-31',
#   'reportedDate': '2017-04-13',
#   'reportedEPS': '1.2629',
#   'estimatedEPS': '1.2404',
#   'surprise': '0.0225',
#   'surprisePercentage': '1.8139'},
#  {'fiscalDateEnding': '2016-12-31',
#   'reportedDate': '2017-01-18',
#   'reportedEPS': '1.14',
#   'estimatedEPS': '1.122',
#   'surprise': '0.018',
#   'surprisePercentage': '1.6043'},
#  {'fiscalDateEnding': '2016-09-30',
#   'reportedDate': '2016-10-14',
#   'reportedEPS': '1.24',
#   'estimatedEPS': '1.1641',
#   'surprise': '0.0759',
#   'surprisePercentage': '6.5201'},
#  {'fiscalDateEnding': '2016-06-30',
#   'reportedDate': '2016-07-15',
#   'reportedEPS': '1.24',
#   'estimatedEPS': '1.1045',
#   'surprise': '0.1355',
#   'surprisePercentage': '12.268'},
#  {'fiscalDateEnding': '2016-03-31',
#   'reportedDate': '2016-04-15',
#   'reportedEPS': '1.1',
#   'estimatedEPS': '1.048',
#   'surprise': '0.052',
#   'surprisePercentage': '4.9618'},
#  {'fiscalDateEnding': '2015-12-31',
#   'reportedDate': '2016-01-15',
#   'reportedEPS': '1.06',
#   'estimatedEPS': '1.066',
#   'surprise': '-0.006',
#   'surprisePercentage': '-0.5629'},
#  {'fiscalDateEnding': '2015-09-30',
#   'reportedDate': '2015-10-15',
#   'reportedEPS': '1.35',
#   'estimatedEPS': '1.28',
#   'surprise': '0.07',
#   'surprisePercentage': '5.4688'},
#  {'fiscalDateEnding': '2015-06-30',
#   'reportedDate': '2015-07-16',
#   'reportedEPS': '1.51',
#   'estimatedEPS': '1.34',
#   'surprise': '0.17',
#   'surprisePercentage': '12.6866'},
#  {'fiscalDateEnding': '2015-03-31',
#   'reportedDate': '2015-04-02',
#   'reportedEPS': '1.51',
#   'estimatedEPS': '1.39',
#   'surprise': '0.12',
#   'surprisePercentage': '8.6331'},
#  {'fiscalDateEnding': '2014-12-31',
#   'reportedDate': '2015-01-15',
#   'reportedEPS': '0.06',
#   'estimatedEPS': '0.09',
#   'surprise': '-0.03',
#   'surprisePercentage': '-33.3333'},
#  {'fiscalDateEnding': '2014-09-30',
#   'reportedDate': '2014-10-14',
#   'reportedEPS': '1.15',
#   'estimatedEPS': '1.12',
#   'surprise': '0.03',
#   'surprisePercentage': '2.6786'},
#  {'fiscalDateEnding': '2014-06-30',
#   'reportedDate': '2014-07-14',
#   'reportedEPS': '1.24',
#   'estimatedEPS': '1.05',
#   'surprise': '0.19',
#   'surprisePercentage': '18.0952'},
#  {'fiscalDateEnding': '2014-03-31',
#   'reportedDate': '2014-04-14',
#   'reportedEPS': '1.3',
#   'estimatedEPS': '1.14',
#   'surprise': '0.16',
#   'surprisePercentage': '14.0351'},
#  {'fiscalDateEnding': '2013-12-31',
#   'reportedDate': '2014-01-16',
#   'reportedEPS': '0.82',
#   'estimatedEPS': '0.95',
#   'surprise': '-0.13',
#   'surprisePercentage': '-13.6842'},
#  {'fiscalDateEnding': '2013-09-30',
#   'reportedDate': '2013-10-15',
#   'reportedEPS': '1.02',
#   'estimatedEPS': '1.04',
#   'surprise': '-0.02',
#   'surprisePercentage': '-1.9231'},
#  {'fiscalDateEnding': '2013-06-30',
#   'reportedDate': '2013-07-15',
#   'reportedEPS': '1.25',
#   'estimatedEPS': '1.17',
#   'surprise': '0.08',
#   'surprisePercentage': '6.8376'},
#  {'fiscalDateEnding': '2013-03-31',
#   'reportedDate': '2013-04-15',
#   'reportedEPS': '1.29',
#   'estimatedEPS': '1.17',
#   'surprise': '0.12',
#   'surprisePercentage': '10.2564'},
#  {'fiscalDateEnding': '2012-12-31',
#   'reportedDate': '2013-01-17',
#   'reportedEPS': '0.69',
#   'estimatedEPS': '0.96',
#   'surprise': '-0.27',
#   'surprisePercentage': '-28.125'},
#  {'fiscalDateEnding': '2012-09-30',
#   'reportedDate': '2012-10-15',
#   'reportedEPS': '1.06',
#   'estimatedEPS': '0.96',
#   'surprise': '0.1',
#   'surprisePercentage': '10.4167'},
#  {'fiscalDateEnding': '2012-06-30',
#   'reportedDate': '2012-07-16',
#   'reportedEPS': '1',
#   'estimatedEPS': '0.89',
#   'surprise': '0.11',
#   'surprisePercentage': '12.3596'},
#  {'fiscalDateEnding': '2012-03-31',
#   'reportedDate': '2012-04-16',
#   'reportedEPS': '1.11',
#   'estimatedEPS': '1',
#   'surprise': '0.11',
#   'surprisePercentage': '11'},
#  {'fiscalDateEnding': '2011-12-31',
#   'reportedDate': '2012-01-17',
#   'reportedEPS': '0.38',
#   'estimatedEPS': '0.49',
#   'surprise': '-0.11',
#   'surprisePercentage': '-22.449'},
#  {'fiscalDateEnding': '2011-09-30',
#   'reportedDate': '2011-10-17',
#   'reportedEPS': '1.23',
#   'estimatedEPS': '0.81',
#   'surprise': '0.42',
#   'surprisePercentage': '51.8519'},
#  {'fiscalDateEnding': '2011-06-30',
#   'reportedDate': '2011-07-15',
#   'reportedEPS': '1.09',
#   'estimatedEPS': '0.96',
#   'surprise': '0.13',
#   'surprisePercentage': '13.5417'},
#  {'fiscalDateEnding': '2011-03-31',
#   'reportedDate': '2011-04-18',
#   'reportedEPS': '1',
#   'estimatedEPS': '0.92',
#   'surprise': '0.08',
#   'surprisePercentage': '8.6957'},
#  {'fiscalDateEnding': '2010-12-31',
#   'reportedDate': '2011-01-18',
#   'reportedEPS': '0.4',
#   'estimatedEPS': '0.77',
#   'surprise': '-0.37',
#   'surprisePercentage': '-48.0519'},
#  {'fiscalDateEnding': '2010-09-30',
#   'reportedDate': '2010-10-18',
#   'reportedEPS': '0.7',
#   'estimatedEPS': '0.57',
#   'surprise': '0.13',
#   'surprisePercentage': '22.807'},
#  {'fiscalDateEnding': '2010-06-30',
#   'reportedDate': '2010-07-16',
#   'reportedEPS': '0.9',
#   'estimatedEPS': '0.48',
#   'surprise': '0.42',
#   'surprisePercentage': '87.5'},
#  {'fiscalDateEnding': '2010-03-31',
#   'reportedDate': '2010-04-19',
#   'reportedEPS': '1.5',
#   'estimatedEPS': '-0.03',
#   'surprise': '1.53',
#   'surprisePercentage': '5100'},
#  {'fiscalDateEnding': '2009-12-31',
#   'reportedDate': '2010-01-19',
#   'reportedEPS': '-3.3',
#   'estimatedEPS': '-3.26',
#   'surprise': '-0.04',
#   'surprisePercentage': '-1.227'},
#  {'fiscalDateEnding': '2009-09-30',
#   'reportedDate': '2009-10-15',
#   'reportedEPS': '-2.7',
#   'estimatedEPS': '-3.83',
#   'surprise': '1.13',
#   'surprisePercentage': '29.5039'},
#  {'fiscalDateEnding': '2009-06-30',
#   'reportedDate': '2009-07-17',
#   'reportedEPS': '4.9',
#   'estimatedEPS': '-3.72',
#   'surprise': '8.62',
#   'surprisePercentage': '231.7204'},
#  {'fiscalDateEnding': '2009-03-31',
#   'reportedDate': '2009-04-17',
#   'reportedEPS': '-1.8',
#   'estimatedEPS': '-3.42',
#   'surprise': '1.62',
#   'surprisePercentage': '47.3684'},
#  {'fiscalDateEnding': '2008-12-31',
#   'reportedDate': '2009-01-16',
#   'reportedEPS': '-24.4',
#   'estimatedEPS': '-13.14',
#   'surprise': '-11.26',
#   'surprisePercentage': '-85.6925'},
#  {'fiscalDateEnding': '2008-09-30',
#   'reportedDate': '2008-10-16',
#   'reportedEPS': '-6',
#   'estimatedEPS': '-7.01',
#   'surprise': '1.01',
#   'surprisePercentage': '14.408'},
#  {'fiscalDateEnding': '2008-06-30',
#   'reportedDate': '2008-07-18',
#   'reportedEPS': '-5.4',
#   'estimatedEPS': '-6.58',
#   'surprise': '1.18',
#   'surprisePercentage': '17.9331'},
#  {'fiscalDateEnding': '2008-03-31',
#   'reportedDate': '2008-04-18',
#   'reportedEPS': '-10.2',
#   'estimatedEPS': '-9.48',
#   'surprise': '-0.72',
#   'surprisePercentage': '-7.5949'},
#  {'fiscalDateEnding': '2007-12-31',
#   'reportedDate': '2008-01-15',
#   'reportedEPS': '-19.9',
#   'estimatedEPS': '-10.32',
#   'surprise': '-9.58',
#   'surprisePercentage': '-92.8295'},
#  {'fiscalDateEnding': '2007-09-30',
#   'reportedDate': '2007-10-15',
#   'reportedEPS': '4.4',
#   'estimatedEPS': '4.37',
#   'surprise': '0.03',
#   'surprisePercentage': '0.6865'},
#  {'fiscalDateEnding': '2007-06-30',
#   'reportedDate': '2007-07-20',
#   'reportedEPS': '12.4',
#   'estimatedEPS': '11.32',
#   'surprise': '1.08',
#   'surprisePercentage': '9.5406'},
#  {'fiscalDateEnding': '2007-03-31',
#   'reportedDate': '2007-04-16',
#   'reportedEPS': '10.1',
#   'estimatedEPS': '10.93',
#   'surprise': '-0.83',
#   'surprisePercentage': '-7.5938'},
#  {'fiscalDateEnding': '2006-12-31',
#   'reportedDate': '2007-01-19',
#   'reportedEPS': '10.3',
#   'estimatedEPS': '10.03',
#   'surprise': '0.27',
#   'surprisePercentage': '2.6919'},
#  {'fiscalDateEnding': '2006-09-30',
#   'reportedDate': '2006-10-19',
#   'reportedEPS': '10.6',
#   'estimatedEPS': '10.31',
#   'surprise': '0.29',
#   'surprisePercentage': '2.8128'},
#  {'fiscalDateEnding': '2006-06-30',
#   'reportedDate': '2006-07-17',
#   'reportedEPS': '10.5',
#   'estimatedEPS': '10.57',
#   'surprise': '-0.07',
#   'surprisePercentage': '-0.6623'},
#  {'fiscalDateEnding': '2006-03-31',
#   'reportedDate': '2006-04-17',
#   'reportedEPS': '11.1',
#   'estimatedEPS': '10.23',
#   'surprise': '0.87',
#   'surprisePercentage': '8.5044'},
#  {'fiscalDateEnding': '2005-12-31',
#   'reportedDate': '2006-01-20',
#   'reportedEPS': '9.8',
#   'estimatedEPS': '9.99',
#   'surprise': '-0.19',
#   'surprisePercentage': '-1.9019'},
#  {'fiscalDateEnding': '2005-09-30',
#   'reportedDate': '2005-10-17',
#   'reportedEPS': '9.7',
#   'estimatedEPS': '9.93',
#   'surprise': '-0.23',
#   'surprisePercentage': '-2.3162'},
#  {'fiscalDateEnding': '2005-06-30',
#   'reportedDate': '2005-07-18',
#   'reportedEPS': '9.7',
#   'estimatedEPS': '10.18',
#   'surprise': '-0.48',
#   'surprisePercentage': '-4.7151'},
#  {'fiscalDateEnding': '2005-03-31',
#   'reportedDate': '2005-04-15',
#   'reportedEPS': '10.4',
#   'estimatedEPS': '10.22',
#   'surprise': '0.18',
#   'surprisePercentage': '1.7613'},
#  {'fiscalDateEnding': '2004-12-31',
#   'reportedDate': '2005-01-20',
#   'reportedEPS': '10.2',
#   'estimatedEPS': '10.13',
#   'surprise': '0.07',
#   'surprisePercentage': '0.691'},
#  {'fiscalDateEnding': '2004-09-30',
#   'reportedDate': '2004-10-14',
#   'reportedEPS': '10.2',
#   'estimatedEPS': '9.89',
#   'surprise': '0.31',
#   'surprisePercentage': '3.1345'},
#  {'fiscalDateEnding': '2004-06-30',
#   'reportedDate': '2004-07-15',
#   'reportedEPS': '10.2',
#   'estimatedEPS': '9.74',
#   'surprise': '0.46',
#   'surprisePercentage': '4.7228'},
#  {'fiscalDateEnding': '2004-03-31',
#   'reportedDate': '2004-04-15',
#   'reportedEPS': '9.8',
#   'estimatedEPS': '9.45',
#   'surprise': '0.35',
#   'surprisePercentage': '3.7037'},
#  {'fiscalDateEnding': '2003-12-31',
#   'reportedDate': '2004-01-20',
#   'reportedEPS': '9.1',
#   'estimatedEPS': '8.96',
#   'surprise': '0.14',
#   'surprisePercentage': '1.5625'},
#  {'fiscalDateEnding': '2003-09-30',
#   'reportedDate': '2003-10-20',
#   'reportedEPS': '9',
#   'estimatedEPS': '8.48',
#   'surprise': '0.52',
#   'surprisePercentage': '6.1321'},
#  {'fiscalDateEnding': '2003-06-30',
#   'reportedDate': '2003-07-14',
#   'reportedEPS': '8.3',
#   'estimatedEPS': '8.01',
#   'surprise': '0.29',
#   'surprisePercentage': '3.6205'},
#  {'fiscalDateEnding': '2003-03-31',
#   'reportedDate': '2003-04-14',
#   'reportedEPS': '7.9',
#   'estimatedEPS': '7.75',
#   'surprise': '0.15',
#   'surprisePercentage': '1.9355'},
#  {'fiscalDateEnding': '2002-12-31',
#   'reportedDate': '2003-01-21',
#   'reportedEPS': '4.7',
#   'estimatedEPS': '4.59',
#   'surprise': '0.11',
#   'surprisePercentage': '2.3965'},
#  {'fiscalDateEnding': '2002-09-30',
#   'reportedDate': '2002-10-15',
#   'reportedEPS': '7.4',
#   'estimatedEPS': '7.29',
#   'surprise': '0.11',
#   'surprisePercentage': '1.5089'},
#  {'fiscalDateEnding': '2002-06-30',
#   'reportedDate': '2002-07-17',
#   'reportedEPS': '7.5',
#   'estimatedEPS': '7.71',
#   'surprise': '-0.21',
#   'surprisePercentage': '-2.7237'},
#  {'fiscalDateEnding': '2002-03-31',
#   'reportedDate': '2002-04-15',
#   'reportedEPS': '6.7',
#   'estimatedEPS': '7.77',
#   'surprise': '-1.07',
#   'surprisePercentage': '-13.7709'},
#  {'fiscalDateEnding': '2001-12-31',
#   'reportedDate': '2002-01-17',
#   'reportedEPS': '7.4',
#   'estimatedEPS': '7.27',
#   'surprise': '0.13',
#   'surprisePercentage': '1.7882'},
#  {'fiscalDateEnding': '2001-09-30',
#   'reportedDate': '2001-10-17',
#   'reportedEPS': '6.3',
#   'estimatedEPS': '6.34',
#   'surprise': '-0.04',
#   'surprisePercentage': '-0.6309'},
#  {'fiscalDateEnding': '2001-06-30',
#   'reportedDate': '2001-07-16',
#   'reportedEPS': '7.4',
#   'estimatedEPS': '7.34',
#   'surprise': '0.06',
#   'surprisePercentage': '0.8174'},
#  {'fiscalDateEnding': '2001-03-31',
#   'reportedDate': '2001-04-16',
#   'reportedEPS': '7.1',
#   'estimatedEPS': '7.04',
#   'surprise': '0.06',
#   'surprisePercentage': '0.8523'},
#  {'fiscalDateEnding': '2000-12-31',
#   'reportedDate': '2001-01-16',
#   'reportedEPS': '6.5',
#   'estimatedEPS': '6.64',
#   'surprise': '-0.14',
#   'surprisePercentage': '-2.1084'},
#  {'fiscalDateEnding': '2000-09-30',
#   'reportedDate': '2000-10-17',
#   'reportedEPS': '6.7',
#   'estimatedEPS': '6.5',
#   'surprise': '0.2',
#   'surprisePercentage': '3.0769'},
#  {'fiscalDateEnding': '2000-06-30',
#   'reportedDate': '2000-07-19',
#   'reportedEPS': '6.53',
#   'estimatedEPS': '6.2',
#   'surprise': '0.33',
#   'surprisePercentage': '5.3226'},
#  {'fiscalDateEnding': '2000-03-31',
#   'reportedDate': '2000-04-17',
#   'reportedEPS': '8.03',
#   'estimatedEPS': '5.85',
#   'surprise': '2.18',
#   'surprisePercentage': '37.265'},
#  {'fiscalDateEnding': '1999-12-31',
#   'reportedDate': '2000-01-18',
#   'reportedEPS': '5.63',
#   'estimatedEPS': '5.24',
#   'surprise': '0.39',
#   'surprisePercentage': '7.4427'},
#  {'fiscalDateEnding': '1999-09-30',
#   'reportedDate': '1999-10-18',
#   'reportedEPS': '5.25',
#   'estimatedEPS': '5.11',
#   'surprise': '0.14',
#   'surprisePercentage': '2.7397'},
#  {'fiscalDateEnding': '1999-06-30',
#   'reportedDate': '1999-07-19',
#   'reportedEPS': '5.33',
#   'estimatedEPS': '4.87',
#   'surprise': '0.46',
#   'surprisePercentage': '9.4456'},
#  {'fiscalDateEnding': '1999-03-31',
#   'reportedDate': '1999-04-19',
#   'reportedEPS': '5.3',
#   'estimatedEPS': '4.35',
#   'surprise': '0.95',
#   'surprisePercentage': '21.8391'},
#  {'fiscalDateEnding': '1998-12-31',
#   'reportedDate': '1999-01-25',
#   'reportedEPS': '3',
#   'estimatedEPS': '2.78',
#   'surprise': '0.22',
#   'surprisePercentage': '7.9137'},
#  {'fiscalDateEnding': '1998-09-30',
#   'reportedDate': '1998-10-21',
#   'reportedEPS': '1.5',
#   'estimatedEPS': '1.43',
#   'surprise': '0.07',
#   'surprisePercentage': '4.8951'},
#  {'fiscalDateEnding': '1998-06-30',
#   'reportedDate': '1998-07-20',
#   'reportedEPS': '4',
#   'estimatedEPS': '3.84',
#   'surprise': '0.16',
#   'surprisePercentage': '4.1667'},
#  {'fiscalDateEnding': '1998-03-31',
#   'reportedDate': '1998-04-20',
#   'reportedEPS': '4.2',
#   'estimatedEPS': '3.79',
#   'surprise': '0.41',
#   'surprisePercentage': '10.8179'},
#  {'fiscalDateEnding': '1997-12-31',
#   'reportedDate': '1998-01-26',
#   'reportedEPS': '3',
#   'estimatedEPS': '2.9',
#   'surprise': '0.1',
#   'surprisePercentage': '3.4483'},
#  {'fiscalDateEnding': '1997-09-30',
#   'reportedDate': '1997-10-13',
#   'reportedEPS': '3.73',
#   'estimatedEPS': '3.36',
#   'surprise': '0.37',
#   'surprisePercentage': '11.0119'},
#  {'fiscalDateEnding': '1997-06-30',
#   'reportedDate': '1997-07-15',
#   'reportedEPS': '3.3',
#   'estimatedEPS': '3.13',
#   'surprise': '0.17',
#   'surprisePercentage': '5.4313'},
#  {'fiscalDateEnding': '1997-03-31',
#   'reportedDate': '1997-04-13',
#   'reportedEPS': '3.17',
#   'estimatedEPS': '3.06',
#   'surprise': '0.11',
#   'surprisePercentage': '3.5948'},
#  {'fiscalDateEnding': '1996-12-31',
#   'reportedDate': '1996-12-31',
#   'reportedEPS': '3.3617',
#   'estimatedEPS': 'None',
#   'surprise': 'None',
#   'surprisePercentage': 'None'},
#  {'fiscalDateEnding': '1996-09-30',
#   'reportedDate': '1996-09-30',
#   'reportedEPS': '3.0881',
#   'estimatedEPS': 'None',
#   'surprise': 'None',
#   'surprisePercentage': 'None'},
#  {'fiscalDateEnding': '1996-06-30',
#   'reportedDate': '1996-06-30',
#   'reportedEPS': '3.0252',
#   'estimatedEPS': 'None',
#   'surprise': 'None',
#   'surprisePercentage': 'None'},
#  {'fiscalDateEnding': '1996-03-31',
#   'reportedDate': '1996-03-31',
#   'reportedEPS': '2.7185',
#   'estimatedEPS': 'None',
#   'surprise': 'None',
#   'surprisePercentage': 'None'}]

# %%
output2['annualEarnings']
# Out:
# [{'fiscalDateEnding': '2022-03-31', 'reportedEPS': '0'},
#  {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '10.07'},
#  {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '5.04'},
#  {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '7.57'},
#  {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '6.65'},
#  {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '5.0329'},
#  {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '4.72'},
#  {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '5.43'},
#  {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '3.75'},
#  {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '4.38'},
#  {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '3.86'},
#  {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '3.7'},
#  {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '3.5'},
#  {'fiscalDateEnding': '2009-12-31', 'reportedEPS': '-2.9'},
#  {'fiscalDateEnding': '2008-12-31', 'reportedEPS': '-46'},
#  {'fiscalDateEnding': '2007-12-31', 'reportedEPS': '7'},
#  {'fiscalDateEnding': '2006-12-31', 'reportedEPS': '42.5'},
#  {'fiscalDateEnding': '2005-12-31', 'reportedEPS': '39.6'},
#  {'fiscalDateEnding': '2004-12-31', 'reportedEPS': '40.4'},
#  {'fiscalDateEnding': '2003-12-31', 'reportedEPS': '34.3'},
#  {'fiscalDateEnding': '2002-12-31', 'reportedEPS': '26.3'},
#  {'fiscalDateEnding': '2001-12-31', 'reportedEPS': '28.2'},
#  {'fiscalDateEnding': '2000-12-31', 'reportedEPS': '27.76'},
#  {'fiscalDateEnding': '1999-12-31', 'reportedEPS': '21.51'},
#  {'fiscalDateEnding': '1998-12-31', 'reportedEPS': '12.7'},
#  {'fiscalDateEnding': '1997-12-31', 'reportedEPS': '13.2'},
#  {'fiscalDateEnding': '1996-12-31', 'reportedEPS': '12.1935'}]

# %%
session.rollback()

# %%
session.execute("drop table stock_meta")

# %%
abs(int(output['annualReports'][0]['incomeTaxExpense']))/1_000_000_000
# Out:
# 0.743

# %%
Base.metadata.create_all(engine)

# %%
with Session(engine) as session:
    session.execute('drop table stock_symbol_mapping')

# %%
# Institution Level / Bluechip companies
tier1_searchTerms = [ 'McKesson', 'Exxon Mobil',' AmerisourceBergen', 
 'Berkshire Hathaway']

tier2_searchTerms = ['Costco', 'ebay', 'gamestop', 'Pepco', 'Home Depot', 'Target', 'Pfizer', 'Boeing', 'Ford', 'General Motors', 'ConocoPhilips', 
'Bank of America', 'Hewlett-Packard', 'Sears Holding', 'PepsiCo', 'MetLife', 'Kraft Foods', 'Dell Inc', 'Best Buy', 'Freddie Mac', 'Nordstrom, Inc', 'New York Life Insurance', 'Visa', 'Fannie Mae',
'Delta Airlines', 'United Airlines', 'American International Group', 'Proctor & Gamble', 'DuPont', 'United Parcel Service', 'Yellow Freight System', 'Schneider', 'Roadway Express'
]

payload = {
    "function" : "SYMBOL_SEARCH",
    # "maturity" :  '30year',
    "apikey": os.environ['ALPHA_VANTAGE']
}
# with Session(engine) as session:
    # for company in tier2_searchTerms:
    #     payload['keywords'] = company
    #     r = requests.get(url, payload)
    #     output = json.loads(r.text)
    #     for stock in output['bestMatches'][:5]:
    #         session.add(Stock_Mapper(symbol = stock['1. symbol'], company_name = stock['2. name'], region = stock['4. region'], currency = stock['8. currency'], asset_type = stock['3. type'], marketOpen = stock['5. marketOpen'], marketClose= stock['6. marketClose'], timezone = stock['7. timezone']))
    #     session.commit() 
    #     print("Finished", company)   
    #     time.sleep(13)

# %%
session = Session(engine)

# %%
))

# %%
session.query(Stock_Meta).filter( ~ exists().where(Stock_Mapper.symbol == Stock_Meta.symbol)).all()
# Out:
# []

# %%
session.execute(select(Stock_Meta)).all()
# Out:
# []

# %%
output['Description'][:255]
# Out:
# "Apple Inc. is an American multinational technology company that specializes in consumer electronics, computer software, and online services. Apple is the world's largest technology company by revenue (totalling $274.5 billion in 2020) and, since January 2"

# %%
payload['function'] = 'OVERVIEW'
for val in session.execute(select(Stock_Mapper.symbol).filter(Stock_Mapper.region == 'United States').filter(Stock_Mapper.asset_type=='Equity')).all():
    payload['symbol'] = val[0]
    r = requests.get(url, payload)
    output = json.loads(r.text)
    if bool(output):
        session.add(Stock_Meta(symbol = output['Symbol'], assetSubType = output['AssetType'], 
        companyFullName=output['Name'], cik = output['CIK'],
        exchange = output['Exchange'], currency = output['Currency'], country = output ['Country'], sector = output['Sector'], industry = output['Industry'], address = output['Address'],
        fiscalYearEnd = output['FiscalYearEnd']
        ))
        session.commit()
    time.sleep(13)

# %%
val
# Out:
# ('CAKFF',)

# %%
def adjust_output(output, denom_mapper, mode='annualReports'):
    for report in output[mode]:
        takeBreak = False
        annualReport = {}
        for key, val in denom_mapper.items():
            for col, value in report.items():
                try:
                    newNum = float(value)/val
                    annualReport[col] = newNum
                    if newNum > 1:
                        takeBreak = True
                except:
                    annualReport[col] = value
            if bool(takeBreak):
                annualReport['reporting_denominations'] = key
                annualReport['reporting_type'] = ReportingTypes._member_map_[mode]
                break
        yield annualReport

# %%
ReportingTypes._member_map_
# Out:
# {'quarterlyReports': <ReportingTypes.quarterlyReports: 1>,
#  'annualReports': <ReportingTypes.annualReports: 2>}

# %%
[annual_statement for annual_statement in adjust_output(output, denom_mapper)][0]
# Out:
# {'fiscalDateEnding': '2021-12-31',
#  'reportedCurrency': 'USD',
#  'grossProfit': 273.474,
#  'totalRevenue': 285.64,
#  'costOfRevenue': 12.166,
#  'costofGoodsAndServicesSold': 211.806,
#  'operatingIncome': 261.404,
#  'sellingGeneralAndAdministrative': 9.574,
#  'researchAndDevelopment': 0.843,
#  'operatingExpenses': 12.07,
#  'investmentIncomeNet': 0.033,
#  'netInterestIncome': -0.947,
#  'interestIncome': 5.71,
#  'interestExpense': 0.947,
#  'nonInterestIncome': 276.674,
#  'otherNonOperatingIncome': 2.291,
#  'depreciation': 'None',
#  'depreciationAndAmortization': 20.607,
#  'incomeBeforeTax': 30.676,
#  'incomeTaxExpense': 7.636,
#  'interestAndDebtExpense': 0.947,
#  'netIncomeFromContinuingOperations': 23.598,
#  'comprehensiveIncomeNetOfTax': 25.981,
#  'ebit': 31.623,
#  'ebitda': 52.23,
#  'netIncome': 23.04,
#  'reporting_denominations': 'b',
#  'reporting_type': 'annualReports'}

# %%
# Out:
# <Denominations.k: 1>

# %%
with Session(engine) as session:
    print(session.execute("SHOW TABLES").all())
# Out:
# [('broadcaster',), ('game_meta',), ('income_statements',), ('real_gdp',), ('sov_yc',), ('stock_meta',), ('stock_symbol_mapping',), ('stream_capture',), ('tag_mapper',), ('tag_stream_association',)]

# %%
payload['function'] = "INCOME_STATEMENT"
with Session(engine) as session:
    for row in session.execute(select(Stock_Meta.symbol).filter(Stock_Meta.assetSubType.ilike('%Common%'))).all():
        payload['symbol'] = row[0]
        r = requests.get(url, payload)
        output = json.loads(r.text)
    if bool(output):
        for annualReport in adjust_output(output, denom_mapper):
            session.add(Income_Statement(**annualReport))
        for quarterlyReport in adjust_output(output, denom_mapper):
            session.add(Income_Statement(**quarterlyReport))
        session.commit()
        print("Finished", payload['symbol'])
        time.sleep(13)
# Out:
# ---------------------------------------------------------------------------
# NoReferencedTableError                    Traceback (most recent call last)
# <ipython-input-24-5b02d701dcfb> in <module>
#      10         for quarterlyReport in adjust_output(output, denom_mapper):
#      11             session.add(Income_Statement(**quarterlyReport))
# ---> 12         session.commit()
#      13         print("Finished", payload['symbol'])
#      14         time.sleep(13)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in commit(self)
#    1421                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1422
# -> 1423         self._transaction.commit(_to_root=self.future)
#    1424
#    1425     def prepare(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in commit(self, _to_root)
#     827         self._assert_active(prepared_ok=True)
#     828         if self._state is not PREPARED:
# --> 829             self._prepare_impl()
#     830
#     831         if self._parent is None or self.nested:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in _prepare_impl(self)
#     806                 if self.session._is_clean():
#     807                     break
# --> 808                 self.session.flush()
#     809             else:
#     810                 raise exc.FlushError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in flush(self, objects)
#    3239         try:
#    3240             self._flushing = True
# -> 3241             self._flush(objects)
#    3242         finally:
#    3243             self._flushing = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in _flush(self, objects)
#    3379         except:
#    3380             with util.safe_reraise():
# -> 3381                 transaction.rollback(_capture_exception=True)
#    3382
#    3383     def bulk_save_objects(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in _flush(self, objects)
#    3339             self._warn_on_events = True
#    3340             try:
# -> 3341                 flush_context.execute()
#    3342             finally:
#    3343                 self._warn_on_events = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/unitofwork.py in execute(self)
#     451         else:
#     452             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 453                 rec.execute(self)
#     454
#     455     def finalize_flush_changes(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/unitofwork.py in execute(self, uow)
#     625     @util.preload_module("sqlalchemy.orm.persistence")
#     626     def execute(self, uow):
# --> 627         util.preloaded.orm_persistence.save_obj(
#     628             self.mapper,
#     629             uow.states_for_mapper_hierarchy(self.mapper, False, False),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     223             states_to_insert.append((state, dict_, mapper, connection))
#     224
# --> 225     for table, mapper in base_mapper._sorted_tables.items():
#     226         if table not in mapper._pks_by_table:
#     227             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#    1158             if obj is None:
#    1159                 return self
# -> 1160             obj.__dict__[self.__name__] = result = self.fget(obj)
#    1161             obj._memoized_keys |= {self.__name__}
#    1162             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/mapper.py in _sorted_tables(self)
#    3241             return False
#    3242
# -> 3243         sorted_ = sql_util.sort_tables(
#    3244             table_to_mapper,
#    3245             skip_fn=skip,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in sort_tables(tables, skip_fn, extra_dependencies)
#    1206     return [
#    1207         t
# -> 1208         for (t, fkcs) in sort_tables_and_constraints(
#    1209             tables,
#    1210             filter_fn=_skip_fn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in sort_tables_and_constraints(tables, filter_fn, extra_dependencies, _warn_for_cycles)
#    1278
#    1279             if filter_fn:
# -> 1280                 filtered = filter_fn(fkc)
#    1281
#    1282                 if filtered is True:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in _skip_fn(fkc)
#    1196         def _skip_fn(fkc):
#    1197             for fk in fkc.elements:
# -> 1198                 if skip_fn(fk):
#    1199                     return True
#    1200             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/mapper.py in skip(fk)
#    3224             # not what we mean to sort on here.
#    3225             parent = table_to_mapper.get(fk.parent.table)
# -> 3226             dep = table_to_mapper.get(fk.column.table)
#    3227             if (
#    3228                 parent is not None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#    1091         if obj is None:
#    1092             return self
# -> 1093         obj.__dict__[self.__name__] = result = self.fget(obj)
#    1094         return result
#    1095
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in column(self)
#    2374
#    2375             if tablekey not in parenttable.metadata:
# -> 2376                 raise exc.NoReferencedTableError(
#    2377                     "Foreign key associated with column '%s' could not find "
#    2378                     "table '%s' with which to generate a "
#
# NoReferencedTableError: Foreign key associated with column 'income_statements.symbol' could not find table 'stock_symbol_mapping' with which to generate a foreign key to target column 'symbol'

# %%
r = requests.get(url, payload)
output = json.loads(r.text)

# %%
for i in range(10):
    for n in range(8):
        if n> 2:
            break
    if i > 8:
        print(i)
# Out:
# 9

# %%
id = Column(Integer, primary_key=True)
    symbol = Column(String(35), ForeignKey('stock_symbol_mapping.symbol'))
    reporting_type = Column(Enum(ReportingTypes))
    reporting_denominations = Column(Enum(Denominations))
    fiscalDateEnding = Column(DATE) 
    reportedCurrency = Column(String(3))
# Out:
# {'symbol': 'XOM',
#  'annualReports': [{'fiscalDateEnding': '2021-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '273474000000',
#    'totalRevenue': '285640000000',
#    'costOfRevenue': '12166000000',
#    'costofGoodsAndServicesSold': '211806000000',
#    'operatingIncome': '261404000000',
#    'sellingGeneralAndAdministrative': '9574000000',
#    'researchAndDevelopment': '843000000',
#    'operatingExpenses': '12070000000',
#    'investmentIncomeNet': '33000000',
#    'netInterestIncome': '-947000000',
#    'interestIncome': '5710000000',
#    'interestExpense': '947000000',
#    'nonInterestIncome': '276674000000',
#    'otherNonOperatingIncome': '2291000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '20607000000',
#    'incomeBeforeTax': '30676000000',
#    'incomeTaxExpense': '7636000000',
#    'interestAndDebtExpense': '947000000',
#    'netIncomeFromContinuingOperations': '23598000000',
#    'comprehensiveIncomeNetOfTax': '25981000000',
#    'ebit': '31623000000',
#    'ebitda': '52230000000',
#    'netIncome': '23040000000'},
#   {'fiscalDateEnding': '2020-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '168484000000',
#    'totalRevenue': '181502000000',
#    'costOfRevenue': '13018000000',
#    'costofGoodsAndServicesSold': '170447000000',
#    'operatingIncome': '154366000000',
#    'sellingGeneralAndAdministrative': '10168000000',
#    'researchAndDevelopment': '1016000000',
#    'operatingExpenses': '14118000000',
#    'investmentIncomeNet': '49000000',
#    'netInterestIncome': '-1158000000',
#    'interestIncome': '574000000',
#    'interestExpense': '1158000000',
#    'nonInterestIncome': '178550000000',
#    'otherNonOperatingIncome': '1196000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '46009000000',
#    'incomeBeforeTax': '-28072000000',
#    'incomeTaxExpense': '-5632000000',
#    'interestAndDebtExpense': '1158000000',
#    'netIncomeFromContinuingOperations': '-23251000000',
#    'comprehensiveIncomeNetOfTax': '-19652000000',
#    'ebit': '-26914000000',
#    'ebitda': '19095000000',
#    'netIncome': '-22440000000'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '251556000000',
#    'totalRevenue': '264938000000',
#    'costOfRevenue': '13382000000',
#    'costofGoodsAndServicesSold': '199625000000',
#    'operatingIncome': '238636000000',
#    'sellingGeneralAndAdministrative': '11398000000',
#    'researchAndDevelopment': '1214000000',
#    'operatingExpenses': '12920000000',
#    'investmentIncomeNet': '84000000',
#    'netInterestIncome': '-830000000',
#    'interestIncome': '4611000000',
#    'interestExpense': '830000000',
#    'nonInterestIncome': '255479000000',
#    'otherNonOperatingIncome': '3914000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': 'None',
#    'incomeBeforeTax': '19622000000',
#    'incomeTaxExpense': '5282000000',
#    'interestAndDebtExpense': '830000000',
#    'netIncomeFromContinuingOperations': '14774000000',
#    'comprehensiveIncomeNetOfTax': '14411000000',
#    'ebit': '20452000000',
#    'ebitda': '20452000000',
#    'netIncome': '14340000000'},
#   {'fiscalDateEnding': '2018-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '266471000000',
#    'totalRevenue': '290212000000',
#    'costOfRevenue': '12861000000',
#    'costofGoodsAndServicesSold': '211599000000',
#    'operatingIncome': '253021000000',
#    'sellingGeneralAndAdministrative': '11480000000',
#    'researchAndDevelopment': '1116000000',
#    'operatingExpenses': '13450000000',
#    'investmentIncomeNet': '64000000',
#    'netInterestIncome': '-766000000',
#    'interestIncome': '6589000000',
#    'interestExpense': '766000000',
#    'nonInterestIncome': '-138000000',
#    'otherNonOperatingIncome': '3525000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '18745000000',
#    'incomeBeforeTax': '30372000000',
#    'incomeTaxExpense': '9532000000',
#    'interestAndDebtExpense': '766000000',
#    'netIncomeFromContinuingOperations': '21421000000',
#    'comprehensiveIncomeNetOfTax': '17577000000',
#    'ebit': '31138000000',
#    'ebitda': '49883000000',
#    'netIncome': '20840000000'},
#   {'fiscalDateEnding': '2017-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '225426000000',
#    'totalRevenue': '244363000000',
#    'costOfRevenue': '11736000000',
#    'costofGoodsAndServicesSold': '182238000000',
#    'operatingIncome': '211171000000',
#    'sellingGeneralAndAdministrative': '10649000000',
#    'researchAndDevelopment': '1063000000',
#    'operatingExpenses': '14255000000',
#    'investmentIncomeNet': '36000000',
#    'netInterestIncome': '-601000000',
#    'interestIncome': '4779000000',
#    'interestExpense': '601000000',
#    'nonInterestIncome': '-93000000',
#    'otherNonOperatingIncome': '1821000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '19893000000',
#    'incomeBeforeTax': '18536000000',
#    'incomeTaxExpense': '-1174000000',
#    'interestAndDebtExpense': '601000000',
#    'netIncomeFromContinuingOperations': '19848000000',
#    'comprehensiveIncomeNetOfTax': '25687000000',
#    'ebit': '19137000000',
#    'ebitda': '39030000000',
#    'netIncome': '19710000000'}],
#  'quarterlyReports': [{'fiscalDateEnding': '2021-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '80860000000',
#    'totalRevenue': '84965000000',
#    'costOfRevenue': '4105000000',
#    'costofGoodsAndServicesSold': '61933000000',
#    'operatingIncome': '76695000000',
#    'sellingGeneralAndAdministrative': '2514000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '4165000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-221000000',
#    'interestIncome': '1857000000',
#    'interestExpense': '221000000',
#    'nonInterestIncome': '81287000000',
#    'otherNonOperatingIncome': '1582000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '5661000000',
#    'incomeBeforeTax': '11520000000',
#    'incomeTaxExpense': '2650000000',
#    'interestAndDebtExpense': '221000000',
#    'netIncomeFromContinuingOperations': '9079000000',
#    'comprehensiveIncomeNetOfTax': '11802000000',
#    'ebit': '11741000000',
#    'ebitda': '17402000000',
#    'netIncome': '8870000000'},
#   {'fiscalDateEnding': '2021-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '71349000000',
#    'totalRevenue': '73786000000',
#    'costOfRevenue': '2437000000',
#    'costofGoodsAndServicesSold': '53454000000',
#    'operatingIncome': '68868000000',
#    'sellingGeneralAndAdministrative': '2287000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2481000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-214000000',
#    'interestIncome': '1456000000',
#    'interestExpense': '214000000',
#    'nonInterestIncome': '71892000000',
#    'otherNonOperatingIncome': '224000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4990000000',
#    'incomeBeforeTax': '9414000000',
#    'incomeTaxExpense': '2664000000',
#    'interestAndDebtExpense': '214000000',
#    'netIncomeFromContinuingOperations': '6942000000',
#    'comprehensiveIncomeNetOfTax': '5640000000',
#    'ebit': '9628000000',
#    'ebitda': '14618000000',
#    'netIncome': '6750000000'},
#   {'fiscalDateEnding': '2021-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '65225000000',
#    'totalRevenue': '67742000000',
#    'costOfRevenue': '2517000000',
#    'costofGoodsAndServicesSold': '50752000000',
#    'operatingIncome': '62694000000',
#    'sellingGeneralAndAdministrative': '2345000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2531000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-254000000',
#    'interestIncome': '1182000000',
#    'interestExpense': '254000000',
#    'nonInterestIncome': '65943000000',
#    'otherNonOperatingIncome': '363000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4952000000',
#    'incomeBeforeTax': '6216000000',
#    'incomeTaxExpense': '1526000000',
#    'interestAndDebtExpense': '254000000',
#    'netIncomeFromContinuingOperations': '4781000000',
#    'comprehensiveIncomeNetOfTax': '5194000000',
#    'ebit': '6470000000',
#    'ebitda': '11422000000',
#    'netIncome': '4690000000'},
#   {'fiscalDateEnding': '2021-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '56302000000',
#    'totalRevenue': '59147000000',
#    'costOfRevenue': '2845000000',
#    'costofGoodsAndServicesSold': '45667000000',
#    'operatingIncome': '53671000000',
#    'sellingGeneralAndAdministrative': '2428000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2631000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-258000000',
#    'interestIncome': '1215000000',
#    'interestExpense': '258000000',
#    'nonInterestIncome': '57552000000',
#    'otherNonOperatingIncome': '122000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '5004000000',
#    'incomeBeforeTax': '3526000000',
#    'incomeTaxExpense': '796000000',
#    'interestAndDebtExpense': '258000000',
#    'netIncomeFromContinuingOperations': '2796000000',
#    'comprehensiveIncomeNetOfTax': '3345000000',
#    'ebit': '3784000000',
#    'ebitda': '8788000000',
#    'netIncome': '2730000000'},
#   {'fiscalDateEnding': '2020-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '42650000000',
#    'totalRevenue': '46540000000',
#    'costOfRevenue': '3890000000',
#    'costofGoodsAndServicesSold': '62332000000',
#    'operatingIncome': '37543000000',
#    'sellingGeneralAndAdministrative': '2736000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '5107000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-313000000',
#    'interestIncome': '24000000',
#    'interestExpense': '313000000',
#    'nonInterestIncome': '45714000000',
#    'otherNonOperatingIncome': '465000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '45993282000',
#    'incomeBeforeTax': '-26080000000',
#    'incomeTaxExpense': '-6010000000',
#    'interestAndDebtExpense': '313000000',
#    'netIncomeFromContinuingOperations': '-20603000000',
#    'comprehensiveIncomeNetOfTax': '-16586000000',
#    'ebit': '-25767000000',
#    'ebitda': '20226282000',
#    'netIncome': '-20070000000'},
#   {'fiscalDateEnding': '2020-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '43636000000',
#    'totalRevenue': '46199000000',
#    'costOfRevenue': '2563000000',
#    'costofGoodsAndServicesSold': '-153000000',
#    'operatingIncome': '41004000000',
#    'sellingGeneralAndAdministrative': '2444000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2632000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-279000000',
#    'interestIncome': '238000000',
#    'interestExpense': '279000000',
#    'nonInterestIncome': '45425000000',
#    'otherNonOperatingIncome': '257000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '15718',
#    'incomeBeforeTax': '-343000000',
#    'incomeTaxExpense': '337000000',
#    'interestAndDebtExpense': '279000000',
#    'netIncomeFromContinuingOperations': '-709000000',
#    'comprehensiveIncomeNetOfTax': '748000000',
#    'ebit': '-64000000',
#    'ebitda': '-64000000',
#    'netIncome': '-680000000'},
#   {'fiscalDateEnding': '2020-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '32549000000',
#    'totalRevenue': '32605000000',
#    'costOfRevenue': '56000000',
#    'costofGoodsAndServicesSold': '-2624000000',
#    'operatingIncome': '29926000000',
#    'sellingGeneralAndAdministrative': '2409000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2623000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-317000000',
#    'interestIncome': '-214000000',
#    'interestExpense': '317000000',
#    'nonInterestIncome': '32277000000',
#    'otherNonOperatingIncome': '225000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': 'None',
#    'incomeBeforeTax': '-1551000000',
#    'incomeTaxExpense': '-471000000',
#    'interestAndDebtExpense': '317000000',
#    'netIncomeFromContinuingOperations': '-1169000000',
#    'comprehensiveIncomeNetOfTax': '1642000000',
#    'ebit': '-1234000000',
#    'ebitda': '-1234000000',
#    'netIncome': '-1080000000'},
#   {'fiscalDateEnding': '2020-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '49746000000',
#    'totalRevenue': '56158000000',
#    'costOfRevenue': '6412000000',
#    'costofGoodsAndServicesSold': '2777000000',
#    'operatingIncome': '46088000000',
#    'sellingGeneralAndAdministrative': '2579000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3658000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-249000000',
#    'interestIncome': '526000000',
#    'interestExpense': '249000000',
#    'nonInterestIncome': '55134000000',
#    'otherNonOperatingIncome': '249000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': 'None',
#    'incomeBeforeTax': '-98000000',
#    'incomeTaxExpense': '512000000',
#    'interestAndDebtExpense': '249000000',
#    'netIncomeFromContinuingOperations': '-770000000',
#    'comprehensiveIncomeNetOfTax': '-5456000000',
#    'ebit': '151000000',
#    'ebitda': '151000000',
#    'netIncome': '-610000000'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '63169000000',
#    'totalRevenue': '67173000000',
#    'costOfRevenue': '4004000000',
#    'costofGoodsAndServicesSold': '49177000000',
#    'operatingIncome': '59511000000',
#    'sellingGeneralAndAdministrative': '3048000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3658000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-201000000',
#    'interestIncome': '976000000',
#    'interestExpense': '201000000',
#    'nonInterestIncome': '62920000000',
#    'otherNonOperatingIncome': '2972000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': 'None',
#    'incomeBeforeTax': '6374000000',
#    'incomeTaxExpense': '684000000',
#    'interestAndDebtExpense': '201000000',
#    'netIncomeFromContinuingOperations': '5730000000',
#    'comprehensiveIncomeNetOfTax': '5474000000',
#    'ebit': '6575000000',
#    'ebitda': '6575000000',
#    'netIncome': '5690000000'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '61939000000',
#    'totalRevenue': '65049000000',
#    'costOfRevenue': '3110000000',
#    'costofGoodsAndServicesSold': '49011000000',
#    'operatingIncome': '58887000000',
#    'sellingGeneralAndAdministrative': '2753000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3052000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-232000000',
#    'interestIncome': '964000000',
#    'interestExpense': '232000000',
#    'nonInterestIncome': '63422000000',
#    'otherNonOperatingIncome': '431000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4873000000',
#    'incomeBeforeTax': '4644000000',
#    'incomeTaxExpense': '1474000000',
#    'interestAndDebtExpense': '232000000',
#    'netIncomeFromContinuingOperations': '3247000000',
#    'comprehensiveIncomeNetOfTax': '2098000000',
#    'ebit': '4876000000',
#    'ebitda': '9749000000',
#    'netIncome': '3170000000'},
#   {'fiscalDateEnding': '2019-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '64664000000',
#    'totalRevenue': '69091000000',
#    'costOfRevenue': '2827000000',
#    'costofGoodsAndServicesSold': '53095000000',
#    'operatingIncome': '61504000000',
#    'sellingGeneralAndAdministrative': '2827000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3160000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-216000000',
#    'interestIncome': '1143000000',
#    'interestExpense': '216000000',
#    'nonInterestIncome': '67491000000',
#    'otherNonOperatingIncome': '241000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4631000000',
#    'incomeBeforeTax': '4371000000',
#    'incomeTaxExpense': '1241000000',
#    'interestAndDebtExpense': '216000000',
#    'netIncomeFromContinuingOperations': '3391000000',
#    'comprehensiveIncomeNetOfTax': '3707000000',
#    'ebit': '4587000000',
#    'ebitda': '9218000000',
#    'netIncome': '3130000000'},
#   {'fiscalDateEnding': '2019-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '58876000000',
#    'totalRevenue': '63625000000',
#    'costOfRevenue': '2770000000',
#    'costofGoodsAndServicesSold': '48342000000',
#    'operatingIncome': '55826000000',
#    'sellingGeneralAndAdministrative': '2770000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3050000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-181000000',
#    'interestIncome': '1528000000',
#    'interestExpense': '181000000',
#    'nonInterestIncome': '61646000000',
#    'otherNonOperatingIncome': '270000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4571000000',
#    'incomeBeforeTax': '4233000000',
#    'incomeTaxExpense': '1883000000',
#    'interestAndDebtExpense': '181000000',
#    'netIncomeFromContinuingOperations': '2406000000',
#    'comprehensiveIncomeNetOfTax': '3132000000',
#    'ebit': '4414000000',
#    'ebitda': '8985000000',
#    'netIncome': '2350000000'},
#   {'fiscalDateEnding': '2018-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '64024000000',
#    'totalRevenue': '71895000000',
#    'costOfRevenue': '4229000000',
#    'costofGoodsAndServicesSold': '51985000000',
#    'operatingIncome': '60117000000',
#    'sellingGeneralAndAdministrative': '2848000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3907000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-215000000',
#    'interestIncome': 'None',
#    'interestExpense': '215000000',
#    'nonInterestIncome': '-211217000000',
#    'otherNonOperatingIncome': '1886000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '5028000000',
#    'incomeBeforeTax': '7915000000',
#    'incomeTaxExpense': '1915000000',
#    'interestAndDebtExpense': '215000000',
#    'netIncomeFromContinuingOperations': '6206000000',
#    'comprehensiveIncomeNetOfTax': '4806000000',
#    'ebit': '8130000000',
#    'ebitda': '13158000000',
#    'netIncome': '6000000000'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '71295000000',
#    'totalRevenue': '76605000000',
#    'costOfRevenue': '2892000000',
#    'costofGoodsAndServicesSold': '55531000000',
#    'operatingIncome': '68111000000',
#    'sellingGeneralAndAdministrative': '2892000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3184000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-200000000',
#    'interestIncome': 'None',
#    'interestExpense': '200000000',
#    'nonInterestIncome': '74187000000',
#    'otherNonOperatingIncome': '458000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4658000000',
#    'incomeBeforeTax': '8874000000',
#    'incomeTaxExpense': '2634000000',
#    'interestAndDebtExpense': '200000000',
#    'netIncomeFromContinuingOperations': '6446000000',
#    'comprehensiveIncomeNetOfTax': '6479000000',
#    'ebit': '9074000000',
#    'ebitda': '13732000000',
#    'netIncome': '6240000000'},
#   {'fiscalDateEnding': '2018-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '68463000000',
#    'totalRevenue': '71456000000',
#    'costOfRevenue': '2993000000',
#    'costofGoodsAndServicesSold': '54834000000',
#    'operatingIncome': '65138000000',
#    'sellingGeneralAndAdministrative': '2993000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3325000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-147000000',
#    'interestIncome': 'None',
#    'interestExpense': '147000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '1729000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4589000000',
#    'incomeBeforeTax': '6476000000',
#    'incomeTaxExpense': '2526000000',
#    'interestAndDebtExpense': '147000000',
#    'netIncomeFromContinuingOperations': '3986000000',
#    'comprehensiveIncomeNetOfTax': '2333000000',
#    'ebit': '6623000000',
#    'ebitda': '11212000000',
#    'netIncome': '3950000000'},
#   {'fiscalDateEnding': '2018-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '62689000000',
#    'totalRevenue': '65436000000',
#    'costOfRevenue': '2747000000',
#    'costofGoodsAndServicesSold': '49249000000',
#    'operatingIncome': '59655000000',
#    'sellingGeneralAndAdministrative': '2747000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3034000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-204000000',
#    'interestIncome': 'None',
#    'interestExpense': '204000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '1910000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4470000000',
#    'incomeBeforeTax': '7107000000',
#    'incomeTaxExpense': '2457000000',
#    'interestAndDebtExpense': '204000000',
#    'netIncomeFromContinuingOperations': '4783000000',
#    'comprehensiveIncomeNetOfTax': '3959000000',
#    'ebit': '7311000000',
#    'ebitda': '11781000000',
#    'netIncome': '4650000000'},
#   {'fiscalDateEnding': '2017-12-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '250588000000',
#    'totalRevenue': '72513000000',
#    'costOfRevenue': '-13011000000',
#    'costofGoodsAndServicesSold': '34821000000',
#    'operatingIncome': '244081000000',
#    'sellingGeneralAndAdministrative': '2956000000',
#    'researchAndDevelopment': '1063000000',
#    'operatingExpenses': '5216000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-186000000',
#    'interestIncome': 'None',
#    'interestExpense': '186000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '673000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '5842000000',
#    'incomeBeforeTax': '2988000000',
#    'incomeTaxExpense': '-5392000000',
#    'interestAndDebtExpense': '186000000',
#    'netIncomeFromContinuingOperations': '8409000000',
#    'comprehensiveIncomeNetOfTax': '8769000000',
#    'ebit': '3174000000',
#    'ebitda': '9016000000',
#    'netIncome': '8380000000'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '-8700000000',
#    'totalRevenue': '59350000000',
#    'costOfRevenue': '8589000000',
#    'costofGoodsAndServicesSold': '5864000000',
#    'operatingIncome': '-11431000000',
#    'sellingGeneralAndAdministrative': '2632000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3009000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-111000000',
#    'interestIncome': 'None',
#    'interestExpense': '111000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '1472000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4880000000',
#    'incomeBeforeTax': '5468000000',
#    'incomeTaxExpense': '1498000000',
#    'interestAndDebtExpense': '111000000',
#    'netIncomeFromContinuingOperations': '4085000000',
#    'comprehensiveIncomeNetOfTax': '6221000000',
#    'ebit': '5579000000',
#    'ebitda': '10459000000',
#    'netIncome': '3970000000'},
#   {'fiscalDateEnding': '2017-06-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '-8375000000',
#    'totalRevenue': '56026000000',
#    'costOfRevenue': '8217000000',
#    'costofGoodsAndServicesSold': '5589000000',
#    'operatingIncome': '-10991000000',
#    'sellingGeneralAndAdministrative': '2556000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '3142000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-158000000',
#    'interestIncome': 'None',
#    'interestExpense': '158000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '1525000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4652000000',
#    'incomeBeforeTax': '4242000000',
#    'incomeTaxExpense': '892000000',
#    'interestAndDebtExpense': '158000000',
#    'netIncomeFromContinuingOperations': '3264000000',
#    'comprehensiveIncomeNetOfTax': '5127000000',
#    'ebit': '4400000000',
#    'ebitda': '9052000000',
#    'netIncome': '3350000000'},
#   {'fiscalDateEnding': '2017-03-31',
#    'reportedCurrency': 'USD',
#    'grossProfit': '-8087000000',
#    'totalRevenue': '56474000000',
#    'costOfRevenue': '7941000000',
#    'costofGoodsAndServicesSold': '5342000000',
#    'operatingIncome': '-10488000000',
#    'sellingGeneralAndAdministrative': '2505000000',
#    'researchAndDevelopment': 'None',
#    'operatingExpenses': '2888000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': '-146000000',
#    'interestIncome': 'None',
#    'interestExpense': '146000000',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': '1710000000',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '4519000000',
#    'incomeBeforeTax': '5838000000',
#    'incomeTaxExpense': '1828000000',
#    'interestAndDebtExpense': '146000000',
#    'netIncomeFromContinuingOperations': '4090000000',
#    'comprehensiveIncomeNetOfTax': '5570000000',
#    'ebit': '5984000000',
#    'ebitda': '10503000000',
#    'netIncome': '4010000000'}]}

# %%
output.keys()
# Out:
# dict_keys(['symbol', 'annualReports', 'quarterlyReports'])

# %%
payload['function'] = 'EARNINGS'
payload['symbol'] = 'C'
r = requests.get(url, payload)
output2 = json.loads(r.text)

# %%
payload['function'] = 'INCOME_STATEMENT'
payload['symbol'] = 'BA'
r = requests.get(url, payload)
output = json.loads(r.text)

# %%
for key in output['annualReports'][0].keys():
    if key not in list(output['annualReports'][0].keys()):
        print(key)

# %%
for key in output['quarterlyEarnings'][0].keys():
    if key not in list(output['annualEarnings'][0].keys()):
        print(key)
# Out:
# reportedDate
# estimatedEPS
# surprise
# surprisePercentage

# %%
output2['annualReports'][0]
# Out:
# {'fiscalDateEnding': '2021-12-31',
#  'reportedCurrency': 'USD',
#  'grossProfit': '26678000000',
#  'totalRevenue': '71884000000',
#  'costOfRevenue': '45206000000',
#  'costofGoodsAndServicesSold': 'None',
#  'operatingIncome': '14480000000',
#  'sellingGeneralAndAdministrative': '11632000000',
#  'researchAndDevelopment': 'None',
#  'operatingExpenses': '12198000000',
#  'investmentIncomeNet': 'None',
#  'netInterestIncome': '42494000000',
#  'interestIncome': '50475000000',
#  'interestExpense': '7981000000',
#  'nonInterestIncome': '29390000000',
#  'otherNonOperatingIncome': '1165000000',
#  'depreciation': 'None',
#  'depreciationAndAmortization': '360000000',
#  'incomeBeforeTax': '27403000000',
#  'incomeTaxExpense': '5451000000',
#  'interestAndDebtExpense': '7981000000',
#  'netIncomeFromContinuingOperations': '21945000000',
#  'comprehensiveIncomeNetOfTax': '15245000000',
#  'ebit': '35384000000',
#  'ebitda': '35744000000',
#  'netIncome': '21952000000'}

# %%
{: 'MSFT',
   : 'Microsoft Corporation',
   : 'Equity',
   : 'United States',
   : '09:30',
   : '16:00',
   : 'UTC-04',
   : 'USD',
   '9. matchScore': '0.6154'},
